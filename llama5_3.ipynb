# %% [markdown]
# # 라이브러리 import

# %%
# !pip install bitsandbytes --prefer-binary --extra-index-url=https://jllllll.github.io/bitsandbytes-windows-webui

# %%
# !pip install datasets peft

# import datasets, peft

# %%
# !pip install bitsandbytes --prefer-binary --extra-index-url=https://jllllll.github.io/bitsandbytes-windows-webui

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.4/181.4 kB 17.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.7 MB/s eta 0:00:00
# ...

# %%
import time
import json
import torch
from langchain.document_loaders import PyPDFLoader
from langchain.document_loaders import DirectoryLoader
from langchain.document_loaders import PyPDFDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA
from langchain.document_loaders import PyPDFLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains import RetrievalQA
from langchain.llms import OpenAI
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import CharacterTextSplitter

from langchain.prompts.prompt import PromptTemplate

# %%
# heegyu/polyglot-ko-1.3b-chat
# nayohan/polyglot-ko-1.3b-Inst

# %%
model_name = "heegyu/polyglot-ko-1.3b-chat"

# %%
# Load LLaMA tokenizer
from transformers import AutoModelForCausalLM, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True,language="ko")
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" # Fix weird overflow issue with fp16 training
# Out:
# tokenizer_config.json:   0%|          | 0.00/210 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/185 [00:00<?, ?B/s]

# %%
# example_sentence = "안녕하세요, 토크나이저 테스트 중입니다."
# tokens = tokenizer(example_sentence)
# print(tokens)

# %%
# decoded_tokens = tokenizer.decode(tokens['input_ids'], skip_special_tokens=True)
# print(decoded_tokens)

# %%
# tokens['input_ids']

# %%
# decoded_tokens = tokenizer.decode([17622], skip_special_tokens=True)
# print(decoded_tokens)

# %%
type(tokenizer.vocab)
# Out:
# dict

# %%
type(tokenizer.get_vocab())
# Out:
# dict

# %%
origin_broken_vocab=tokenizer.get_vocab()

# %%
tokenizer
# Out:
# PreTrainedTokenizerFast(name_or_path='heegyu/polyglot-ko-1.3b-chat', vocab_size=30000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'eos_token': '<|endoftext|>', 'pad_token': '<|endoftext|>', 'additional_special_tokens': ['<|endoftext|>', '<|sep|>', '<|acc|>', '<|tel|>', '<|rrn|>']}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("<|unused0|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<|unused1|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	3: AddedToken("<|sep|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	30000: AddedToken("<|acc|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# ...

# %%
tokenizer.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-321effbc7eed> in <cell line: 1>()
# ----> 1 tokenizer.keys()
#
# AttributeError: 'PreTrainedTokenizerFast' object has no attribute 'keys'

# %%
new_vocab={tokenizer.decode(j).strip():j for i,j in tokenizer.get_vocab().items()}

# %%
new_vocab
# Out:
# {'가분': 27203,
#  '패키지': 6353,
#  '일부러': 9067,
#  '래미안': 23167,
#  '황사': 14860,
#  '메모': 7286,
#  '촌': 1883,
#  '모자': 5193,
#  '공공연': 26986,
#  '깜빡': 19957,
#  '호명': 28648,
#  '갈까': 25662,
#  '체크카드': 16852,
#  '톡스': 15510,
#  'xxx': 29317,
#  '그래서인지': 25716,
#  '교체': 9116,
#  '마스터': 7752,
#  '하찮': 27439,
#  '푼': 10408,
#  '정도': 7672,
#  '울릉도': 15700,
#  '재빨리': 12057,
#  '휴지': 20560,
#  '2': 21,
#  '인지도': 11024,
#  '연습': 4350,
#  '올린다': 15062,
#  '고성군': 20670,
#  '부끄러워': 28261,
#  '지체': 12919,
#  '페': 1210,
#  '업로드': 23621,
#  'ers': 13151,
#  '교두': 19870,
#  '안테나': 25945,
#  '강대': 13306,
#  '형': 747,
#  '혼합': 28140,
#  '귀감': 29164,
#  '몰아쉬': 29587,
#  '주워': 19049,
#  '근대': 18299,
#  '폼': 9707,
#  '부여': 16897,
#  '저점': 24500,
#  '르노': 9386,
#  '극도': 14548,
#  '167': 26925,
#  '울': 699,
#  '지향': 15550,
#  '무더': 7151,
#  '상임': 4136,
#  '된다고': 5925,
#  '중대': 16540,
#  '프로': 2562,
#  '옴': 15560,
#  '갤러리': 7989,
#  '넥센': 7350,
#  '속성': 16898,
#  '결연': 19639,
#  '저자': 4722,
#  '관은': 13708,
# ...

# %%
len(new_vocab)
# Out:
# 22565

# %%
new_vocab.keys()
# Out:
# dict_keys(['가분', '패키지', '일부러', '래미안', '황사', '메모', '촌', '모자', '공공연', '깜빡', '호명', '갈까', '체크카드', '톡스', 'xxx', '그래서인지', '교체', '마스터', '하찮', '푼', '정도', '울릉도', '재빨리', '휴지', '2', '인지도', '연습', '올린다', '고성군', '부끄러워', '지체', '페', '업로드', 'ers', '교두', '안테나', '강대', '형', '혼합', '귀감', '몰아쉬', '주워', '근대', '폼', '부여', '저점', '르노', '극도', '167', '울', '지향', '무더', '상임', '된다고', '중대', '프로', '옴', '갤러리', '넥센', '속성', '결연', '저자', '관은', '채울', '용서', '부치', '제로', '물고기', '교육부', '기대감', '소박', '차도', '�', '휴직', '기획', '노동계', '이라', '일찌감치', '방탄', '날리', '태극', '입술', '염', '결승선', '암세포', 'oT', '연합', '투명', '논', '핑계', '색조', '거린다', '덩어리', '착오', '까마', '담', '재원', '강좌', '무서워', '커머스', '예정지', '46', '상승', '성향', '록', '떨', '다스', '더니', '값', '붙잡혔', '밧', '계약', 'ier', '편집자', '리온', '手', '빙', '기수', '시사', '비중', '내린다', '직권상정', '숭', '명나라', '곶', '군산', '나이', '스포츠', '비시', '소프트', '약간', '대검', '발음', '적잖', '까다로운', '70', '왓', '단지', '죄송', 'ff', '수송', '경남기업', '옆', '전신', '속', '랭이', '라우', '기쁨', '늘', '실종', '다문화가정', '네상스', '변별', '끼니', '석유공사', '차분', '챙겼', '두들', '외교', 
# ...

# %%
from tokenizers import BertWordPieceTokenizer

# Initialize an empty BERT tokenizer
tokenizer_1 = BertWordPieceTokenizer(
  clean_text=False,
  handle_chinese_chars=False,
  strip_accents=False,
  lowercase=True,
)

# %%
tokenizer_1
# Out:
# Tokenizer(vocabulary_size=0, model=BertWordPiece, unk_token=[UNK], sep_token=[SEP], cls_token=[CLS], pad_token=[PAD], mask_token=[MASK], clean_text=False, handle_chinese_chars=False, strip_accents=False, lowercase=True, wordpieces_prefix=##)

# %%
type(tokenizer_1.add_tokens(list(new_vocab)))
# Out:
# int

# %%
}a=tokenizer_1.add_tokens(list(new_vocab))

# %%
type(a)
# Out:
# int

# %%
type({tokenizer.decode(j).strip():j for i,j in tokenizer.get_vocab().items()})
# Out:
# dict

# %%
def find_key_by_value(dictionary, target_value):
    return next((key for key, value in dictionary.items() if value == target_value), None)

# %%
find_key_by_value(new_vocab,4196)

# %%
for key in origin_broken_vocab:
    print(key,type(key))
    print(origin_broken_vocab[key],type(origin_broken_vocab[key]))
    print(find_key_by_value(origin_broken_vocab,origin_broken_vocab[key]))

    break
# Out:
# ê°Ģë¶Ħ <class 'str'>
# 27203 <class 'int'>
# ê°Ģë¶Ħ

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3, 'd': 4}

def find_key_by_value(dictionary, target_value):
    return next((key for key, value in dictionary.items() if value == target_value), None)

target_value = 3
found_key = find_key_by_value(my_dict, target_value)

if found_key is not None:
    print(f"The key for value {target_value} is: {found_key}")
else:
    print(f"No key found for value {target_value}")
# Out:
# The key for value 3 is: c

# %%
tokenizer.vocab_size
# Out:
# 30000

# %%
len(tokenizer.get_vocab())
# Out:
# 30003

# %%
from tokenizers import ByteLevelBPETokenizer

# %%
ByteLevelBPETokenizer(tokenizer,)
# Out:
# Tokenizer(vocabulary_size=0, model=ByteLevelBPE, add_prefix_space=False, lowercase=False, dropout=None, unicode_normalizer=None, continuing_subword_prefix=None, end_of_word_suffix=None, trim_offsets=False)

# %%
import os
import torch
from datasets import load_dataset
# from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, HfArgumentParser, TrainingArguments, pipeline, logging

# from peft import LoraConfig, PeftModel,get_peft_model
# from trl import SFTTrainer
from transformers import Trainer
import transformers
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-cfb8f4cb1432> in <cell line: 3>()
#       1 import os
#       2 import torch
# ----> 3 from datasets import load_dataset
#       4 # from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, HfArgumentParser, TrainingArguments, pipeline, logging
#       5
#
# ModuleNotFoundError: No module named 'datasets'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install huggingface_hub

HUGGINGFACEHUB_API_TOKEN = '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'

import os

os.environ["HUGGINGFACEHUB_API_TOKEN"] = HUGGINGFACEHUB_API_TOKEN

# !pip install langchain

# from langchain.llms import HuggingFaceHub
# from langchain.chains import LLMChain
# from langchain.prompts import PromptTemplate

# question = "Who won the FIFA World Cup in the year 1994? "

# template = """Question: {question}

# Answer: Let's think step by step."""

# prompt = PromptTemplate(template=template, input_variables=["question"])

# repo_id = "nayohan/polyglot-ko-1.3b-Inst"

# from langchain.llms import HuggingFacePipeline

# llm = HuggingFacePipeline.from_model_id(
#     model_id=repo_id,
#     device=0,               # -1: CPU(default), 0번 부터는 CUDA 디바이스 번호 지정시 GPU 사용하여 추론
#     task="text-generation", # 텍스트 생성
#     model_kwargs={"temperature": 0.1,
#                   "max_length": 64},
# )


# template = """질문: {question}

# 답변: """

# # 프롬프트 템플릿 생성
# prompt = PromptTemplate.from_template(template)

# # LLM Chain 객체 생성
# llm_chain = LLMChain(prompt=prompt, llm=llm)

# %% [markdown]
# # 데이터 로드

# %%
# %cd drive/My\ Drive/MadeByWoo

# %%
import pickle
import pandas as pd
import numpy as np
from tqdm import tqdm
import random
from IPython.display import Markdown, display

tqdm.pandas()

# %%
# df2 = pd.read_csv('Total_patent_final_merged.csv')

# df2_1 = df2[['제목','요약_x','청구항_원본','법적상태']].copy()

# df2_1['법적상태'] = df2_1['법적상태'].str.replace('[','').str.replace(']','')

# df2_2 = df2_1[['요약_x', '청구항_원본']].copy()

# df2_2.columns = ['요약_splitted','청구_splitted']

# df2_2 = df2_2.fillna('').copy()

# %%
# df2_2 = df2_1[['요약_x', '청구항_원본']].copy()

# df2_2.columns = ['요약_splitted','청구_splitted']

# df2_2 = df2_2.fillna('').copy()

# %%
text_splitter = CharacterTextSplitter(
    chunk_size=512, chunk_overlap=0, separator=" "
)

# %%
# Load model directly
from transformers import ElectraTokenizer, ElectraForPreTraining


tokenizer = ElectraTokenizer.from_pretrained("Pray123/first", token='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',vocab_file = 'vocab.txt')

model_embedding= ElectraForPreTraining.from_pretrained("Pray123/first", token = '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')

# %%
def make_splitter(row):
    A = text_splitter.split_text(text=' '.join(tokenizer.tokenize(row['요약_splitted'])).replace(' ##','').replace('##',''))
    row['요약_splitted'] = A

    A = text_splitter.split_text(text=' '.join(tokenizer.tokenize(row['청구_splitted'])).replace(' ##','').replace('##','').replace('삭제 ',''))
    row['청구_splitted'] = A
    return row

# %%
# true_index = df2_1[[True if '등록' in i else False for i in df2_1['법적상태'].values]].index

# %%
# load
with open('요약_청구_splitted_for_LLM.pickle', 'rb') as f:
    df2_3 = pickle.load(f)

# %%
# # save
# with open('요약_청구_splitted_for_LLM_등록.pickle', 'wb') as f:
#     pickle.dump(df2_3.iloc[true_index,:], f, pickle.HIGHEST_PROTOCOL)

# %%
# # load
# with open('요약_청구_splitted_for_LLM_등록.pickle', 'rb') as f:
#     df2_3 = pickle.load(f)

# %%
# [len(i) for i in df2_3['요약_splitted'][0]]

# %%
df2_3.shape

# %%
def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))

configure_plotly_browser_state()

# %%
# 14 토큰 7168 (7170 자) 가 적절해 보인다.
quantile = pd.DataFrame([len(i) + len(j) for i,j in zip(df2_3['요약_splitted'],df2_3['청구_splitted'])]).quantile(0.75)
quantile

# %%
df2_3['전체_sum'] = df2_3['요약_splitted'] + df2_3['청구_splitted']
df2_4 = df2_3.copy()

# %%
long_index = [True if len(i) >= 10  else False for i in df2_4['전체_sum']]

# %%
short_index = [True if len(i) < 10  else False for i in df2_4['전체_sum'].values]

# %%
# len(df2_4['전체_sum'].values[0])

# %%
# df_old = pd.read_csv('Total_patent_final_merged.csv',encoding = 'utf-8-sig', index_col = None)
# df_old.shape
# df_법적상태 =  pd.DataFrame(df_old['법적상태'].str.replace('[','').str.replace(']','').str.replace('\'','').values, columns = ['법적상태'])

# %%
# len(short_index)

# %%
# df2_5 = df2_4.loc[long_index].copy()

# %%
# np.argmax([len(i[0]) for i in df2_5[['전체_sum']].values])

# %%
# df2_5.reset_index().iloc[2208]

# %%
# seq_a = df2_5.loc[105455,'요약_splitted'].copy()
# seq_b = df2_5.loc[105455,'청구_splitted'].copy()
# seq_ab = df2_5.loc[105455,'요약_splitted'].copy()+ df2_5.loc[105455,'청구_splitted'].copy()

# %%
# len(seq_a), len(seq_b), len(seq_ab)

# %%
# while True:
#     if len(seq_a) + len(seq_b) <= 14:
#         break
#     else:
#         lst_total= truncate_seq_pair(seq_a,seq_b,seq_ab, 14 )

# %%
# lst_total[10] == lst_total[0]

# %%
# len(seq_a), len(seq_b)

# %%
# df2_5.shape

# %%
# df2_3.shape

# %%
# df2_3.loc[short_index].shape

# %% [markdown]
# # 시각화

# %%
# df_concat_short = pd.concat([df2_3[short_index], df_법적상태[short_index]], axis = 1)

# %%
# df_concat_long = pd.concat([df2_3[long_index], df_법적상태[long_index]], axis = 1)

# %%
# configure_plotly_browser_state()
# pd.DataFrame(['등록' if '등록' in i else '나머지' for i in df_concat_short[['법적상태']].values]).iplot('hist')

# %%
# configure_plotly_browser_state()
# pd.DataFrame(['등록' if '등록' in i else '나머지' for i in df_concat_long[['법적상태']].values]).iplot('hist')

# %%
# df_concat_short['요약_all'] = np.array([' '.join(i) for i in df_concat_short['요약_splitted'].values])
# df_concat_short['청구_all'] = np.array([' '.join(i) for i in df_concat_short['청구_splitted'].values])

# %%
# df_concat_short.to_csv('LLM_train.csv',encoding = 'utf-8-sig', index = None)

# %% [markdown]
# # 여기부터

# %%
# # Load datasetq
# dataset = load_dataset('csv', data_files = 'LLM_train.csv', split = 'train')

# %%
# dataset

# %% [markdown]
# # Training Prompt

# %%
512 * 9

# %%
# str(dataset.data['요약_all'][0])

# %% [markdown]
# # 학습 파라미터 설정

# %%
model_name = "nayohan/polyglot-ko-1.3b-Inst"

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

bnb_config = BitsAndBytesConfig(
   load_in_4bit=True,
   bnb_4bit_quant_type="nf4",
   bnb_4bit_use_double_quant=True,
   bnb_4bit_compute_dtype=torch.bfloat16
)

# Load base model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    trust_remote_code=True,
    quantization_config=bnb_config,
    device_map='auto'
)

# %%
# model_name = '42dot/42dot_LLM-SFT-1.3B'

# # Load LLaMA tokenizer
# tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
# tokenizer.pad_token = tokenizer.eos_token
# tokenizer.padding_side = "right" # Fix weird overflow issue with fp16 training

# %%
def generate_prompt(data_point):
    return  f"""해당 특허의 정보는 [요약, 청구항, 법적상태]으로 구성되며 다음과 같이 표시됩니다. 법적상태를 고려하여 요약과 청구항 간의 관계 및 청구항 내의 구성요소를 잘 파악하세요.
    ### 요약:
    {data_point['요약_all']}\n\n
    ### 클레임:
    {data_point['청구_all']}\n\n
    ### 법적상태:
    {data_point['법적상태']}""".strip()


    # features: ['input_ids', 'attention_mask'],

# %%
# Load LLaMA tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" # Fix weird overflow issue with fp16 training

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -f

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
list(tokenizer.vocab.keys())[-100:]

# %%
f = open("vocab.txt", 'r')
lines = f.readlines()
lst = []
for line in lines:
    lst += [line.replace('\n','')]

new_tokens = set(lst) - set(tokenizer.vocab.keys())

tokenizer.add_tokens(list(new_tokens))
model.resize_token_embeddings(len(tokenizer))

# %%
# 주어진 문자열
encoded_text = "Ġê¼¬ë°ķê¼¬ë°ķ"

# UTF-8 디코딩
decoded_text = encoded_text.encode('utf-8')

# 결과 출력
print(decoded_text)

# %%
tokenizer.vocab

# %%
from datasets import load_from_disk

def generate_and_tokenize_prompt(data_point):
    full_prompt = generate_prompt(data_point)
    tokenized_full_prompt = tokenizer(full_prompt)
    return tokenized_full_prompt


# tokenized_datasets = dataset.map(generate_and_tokenize_prompt)

# %%
# # save
# tokenized_datasets.save_to_disk('tokenized_datasets_LLM_smaller_than_10')

# %%
# load
tokenized_datasets = load_from_disk("tokenized_datasets_LLM_smaller_than_9")


tokenized_datasets

tokenized_datasets = tokenized_datasets.remove_columns('요약_splitted')
tokenized_datasets = tokenized_datasets.remove_columns('청구_splitted')
tokenized_datasets = tokenized_datasets.remove_columns('전체_sum')
tokenized_datasets = tokenized_datasets.remove_columns('법적상태')
tokenized_datasets = tokenized_datasets.remove_columns('요약_all')
tokenized_datasets = tokenized_datasets.remove_columns('청구_all')

# %%
tokenized_datasets

# %%
model

# %%
peft_config = LoraConfig(
    r=4,
    lora_alpha=16,
    target_modules=[
        "dense_4h_to_h"
    ],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

# %%
model = get_peft_model(model, peft_config)
model.print_trainable_parameters()

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir 'log2'

# %%
# Initial learning rate (AdamW optimizer)
learning_rate = 2e-6

# Weight decay to apply to all layers except bias/LayerNorm weights
weight_decay = 0.001

# Maximum gradient normal (gradient clipping)
max_grad_norm = 0.3

# Number of training steps (overrides num_train_epochs)
max_steps = -1

# Learning rate schedule
lr_scheduler_type = "cosine"

# %%
tokenized_datasets

# %% [markdown]
# # 학습

# %%
import transformers


trainer = transformers.Trainer(
    model=model,
    train_dataset=tokenized_datasets,
    args=transformers.TrainingArguments(
        per_device_train_batch_size=1,
        gradient_accumulation_steps=1,
        num_train_epochs=1,
        # max_steps=500, ## 초소형만 학습: 10 step = 20개 샘플만 학습.
        learning_rate=2e-4,
        bf16= True, # A100시,
        logging_steps=10,
        save_steps= 1000,
        output_dir='result2',
        save_strategy = 'steps',
        logging_dir='log2',
        optim="paged_adamw_8bit"
    ),
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False),
)
model.config.use_cache = False  # silence the warnings. Please re-enable for inference!

# %%
max([len(i) for i in tokenized_datasets.data['input_ids']])

# %%
configure_plotly_browser_state()

# pd.DataFrame([len(i) for i in tokenized_datasets.data['input_ids']]).iplot('bar')

# %%
# !pip install wandb --upgrade

# %%
# Train model
trainer.train()

# Save trained model
trainer.model.save_pretrained(model)

# %%
model = model.merge_and_unload()

# %%
# Reload tokenizer to save it
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# %%
from huggingface_hub import interpreter_login

interpreter_login()

# %%
model.push_to_hub(new_model, use_temp_dir=False)
tokenizer.push_to_hub(new_model, use_temp_dir=False)
